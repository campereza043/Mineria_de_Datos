# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, learning_curve, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    ConfusionMatrixDisplay,
    roc_curve,
    auc,
    precision_score
)

from sklearn.preprocessing import label_binarize

# %%
df = pd.read_csv("dataset_limpio.csv")
df.head()
# Out:
#          pt       eta      phi  charge     pos_x     pos_y     pos_z  \
# 0  2.400150  0.739663  1.62212     1.0  0.000647  0.000633  0.039879
# 1  1.314830  0.945947 -3.09573     1.0  0.000698  0.000623 -0.029173
# 2  1.384250 -1.488470 -2.93427     1.0  0.000703  0.000611 -0.029091
# 3  0.973126  0.576321 -2.91378     1.0  0.000704  0.000611 -0.020457
# 4  1.697150  1.373240 -2.92621     1.0  0.000701  0.000623 -0.020329
#
#   particle_type  event_id
# 0      electron  22109111
# 1         track  22109111
# 2         track  22109111
# 3         track  22109111
# 4         track  22109111

# %%
# Variables predictoras y objetivo
X = df[["pt", "eta", "phi", "charge", "pos_x", "pos_y", "pos_z"]]
y = df["particle_type"]

# Codificación de etiquetas
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
classes = encoder.classes_

# División entrenamiento-prueba
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.25, random_state=42, stratify=y_encoded
)

# Escalado (por consistencia, aunque RF no lo necesita)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# %%time
param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [None, 10, 20, 30],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "bootstrap": [True, False]
}

grid = GridSearchCV(
    RandomForestClassifier(random_state=42),
    param_grid,
    cv=5,
    n_jobs=-1,
    scoring="accuracy"
)

grid.fit(X_train_scaled, y_train)

print("Mejores hiperparámetros encontrados:")
print(grid.best_params_)

# Modelo final entrenado solo una vez
model_rf = grid.best_estimator_
# Out:
# Mejores hiperparámetros encontrados:
# {'bootstrap': True, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 100}
# CPU times: user 12.6 s, sys: 450 ms, total: 13.1 s
# Wall time: 1h 13min 37s

# %%
y_pred_rf = model_rf.predict(X_test_scaled)

print("=== Reporte de clasificación - Random Forest ===")
print(classification_report(y_test, y_pred_rf, target_names=classes))

cm = confusion_matrix(y_test, y_pred_rf)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap="Blues", values_format="d")
plt.title("Matriz de Confusión - Random Forest (Grid Search)")
plt.show()
# Out:
# === Reporte de clasificación - Random Forest ===
#               precision    recall  f1-score   support
#
#     electron       0.00      0.00      0.00        37
#         muon       0.00      0.00      0.00        99
#       photon       1.00      1.00      1.00        63
#        track       0.98      1.00      0.99      7528
#
#     accuracy                           0.98      7727
#    macro avg       0.50      0.50      0.50      7727
# weighted avg       0.97      0.98      0.97      7727
# /usr/lib/python3/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
precisiones_rf = precision_score(y_test, y_pred_rf, average=None)

plt.figure(figsize=(8,5))
plt.bar(classes, precisiones_rf)
plt.ylabel("Precisión")
plt.xlabel("Clase")
plt.title("Precisión por clase - Random Forest (Grid Search)")
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()
# Out:
# /usr/lib/python3/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
y_test_bin = label_binarize(y_test, classes=np.arange(len(classes)))

y_scores_rf = model_rf.predict_proba(X_test_scaled)

plt.figure(figsize=(10, 7))

for i, clase in enumerate(classes):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_scores_rf[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{clase} (AUC = {roc_auc:.3f})")

plt.plot([0, 1], [0, 1], "k--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Curvas ROC - Random Forest (Grid Search)")
plt.legend()
plt.grid(True)
plt.show()

# %%
train_sizes, train_scores, test_scores = learning_curve(
    RandomForestClassifier(**grid.best_params_, random_state=42),
    X_train_scaled,
    y_train,
    cv=5,
    train_sizes=np.linspace(0.1, 1.0, 8),
    n_jobs=-1
)

train_mean = train_scores.mean(axis=1)
test_mean = test_scores.mean(axis=1)

plt.figure(figsize=(10, 7))
plt.plot(train_sizes, train_mean, marker="o", label="Score entrenamiento")
plt.plot(train_sizes, test_mean, marker="o", label="Score validación")
plt.xlabel("Tamaño del conjunto de entrenamiento")
plt.ylabel("Exactitud")
plt.title("Curva de Aprendizaje - Random Forest (Grid Search)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## SIN TRACKS

# %%
df = pd.read_csv("dataset_limpio_notracks.csv")
df.head()
# Out:
#           pt       eta       phi  charge     pos_x     pos_y     pos_z  \
# 0   2.400150  0.739663  1.622120     1.0  0.000647  0.000633  0.039879
# 1   0.838852 -1.914380  2.947160    -1.0  0.000671  0.000501 -0.012415
# 2   2.646500 -2.273300  0.817141     1.0  0.000773  0.000570  0.002240
# 3   1.736600 -2.463090 -1.792570     1.0  0.002726  0.000183 -0.001184
# 4  35.556000  0.005784  1.834000     0.0  0.000726  0.000609 -0.047592
#
#   particle_type   event_id
# 0      electron   22109111
# 1          muon   22109111
# 2          muon   22109111
# 3          muon   22109111
# 4        photon  652620608

# %%
# Variables predictoras y objetivo
X = df[["pt", "eta", "phi", "charge", "pos_x", "pos_y", "pos_z"]]
y = df["particle_type"]

# Codificación de etiquetas
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
classes = encoder.classes_

# División entrenamiento-prueba
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded, test_size=0.25, random_state=42, stratify=y_encoded
)

# Escalado (por consistencia, aunque RF no lo necesita)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# %%time
param_grid = {
    "n_estimators": [100, 200, 300],
    "max_depth": [None, 10, 20, 30],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4],
    "bootstrap": [True, False]
}

grid = GridSearchCV(
    RandomForestClassifier(random_state=42),
    param_grid,
    cv=5,
    n_jobs=-1,
    scoring="accuracy"
)

grid.fit(X_train_scaled, y_train)

print("Mejores hiperparámetros encontrados:")
print(grid.best_params_)

# Modelo final entrenado solo una vez
model_rf = grid.best_estimator_
# Out:
# Mejores hiperparámetros encontrados:
# {'bootstrap': False, 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# CPU times: user 2.97 s, sys: 155 ms, total: 3.12 s
# Wall time: 4min 1s

# %%
y_pred_rf = model_rf.predict(X_test_scaled)

print("=== Reporte de clasificación - Random Forest ===")
print(classification_report(y_test, y_pred_rf, target_names=classes))

cm = confusion_matrix(y_test, y_pred_rf)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes)
disp.plot(cmap="Blues", values_format="d")
plt.title("Matriz de Confusión - Random Forest (Grid Search)")
plt.show()
# Out:
# === Reporte de clasificación - Random Forest ===
#               precision    recall  f1-score   support
#
#     electron       0.71      0.46      0.56        37
#         muon       0.82      0.93      0.87        99
#       photon       1.00      1.00      1.00        63
#
#     accuracy                           0.86       199
#    macro avg       0.84      0.80      0.81       199
# weighted avg       0.86      0.86      0.85       199

# %%
precisiones_rf = precision_score(y_test, y_pred_rf, average=None)

plt.figure(figsize=(8,5))
plt.bar(classes, precisiones_rf)
plt.ylabel("Precisión")
plt.xlabel("Clase")
plt.title("Precisión por clase - Random Forest (Grid Search)")
plt.ylim(0, 1)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %%
y_test_bin = label_binarize(y_test, classes=np.arange(len(classes)))

y_scores_rf = model_rf.predict_proba(X_test_scaled)

plt.figure(figsize=(10, 7))

for i, clase in enumerate(classes):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_scores_rf[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{clase} (AUC = {roc_auc:.3f})")

plt.plot([0, 1], [0, 1], "k--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Curvas ROC - Random Forest (Grid Search)")
plt.legend()
plt.grid(True)
plt.show()

# %%
train_sizes, train_scores, test_scores = learning_curve(
    RandomForestClassifier(**grid.best_params_, random_state=42),
    X_train_scaled,
    y_train,
    cv=5,
    train_sizes=np.linspace(0.1, 1.0, 8),
    n_jobs=-1
)

train_mean = train_scores.mean(axis=1)
test_mean = test_scores.mean(axis=1)

plt.figure(figsize=(10, 7))
plt.plot(train_sizes, train_mean, marker="o", label="Score entrenamiento")
plt.plot(train_sizes, test_mean, marker="o", label="Score validación")
plt.xlabel("Tamaño del conjunto de entrenamiento")
plt.ylabel("Exactitud")
plt.title("Curva de Aprendizaje - Random Forest (Grid Search)")
plt.legend()
plt.grid(True)
plt.show()
